# %%
import pandas as pd
import plotly.express as px

# %%
df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (10,8))
plt.scatter(x = df.pop, y = df.gdpPercap)
plt.title('Life Expectancy by Population')
plt.xlabel('Population')
plt.ylabel('Life Expectancy')
plt.tight_layout()
plt.show()

# %%
df.pop = df.loc[:, ['pop']].astype(float)

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
tips = px.data.tips(pretty_names=False)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(dpi=100)
plt.scatter(x=tips.total_bill, y=tips.tip, s=tips.tip, c=tips.tip, cmap='viridis')
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.tight_layout()
plt.colorbar()
plt.show()

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
pd.Categorical(tips.smoker, categories=['Yes', 'No'])
# Out:
# ['No', 'No', 'No', 'No', 'No', ..., 'No', 'Yes', 'Yes', 'No', 'No']
# Length: 244
# Categories (2, object): ['Yes', 'No']

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
n = 100
x = np.random.normal(0, 1, n)
y = np.random.normal(0, 1, n)
categories = np.random.choice(['A', 'B', 'C'], n)

# Plot the scatter plot
plt.scatter(x, y, c=categories, cmap='viridis')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4213             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4214                 colors = mcolors.to_rgba_array(c)
#    4215             except (TypeError, ValueError) as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
# ...

# %%
import seaborn as sns

# %%
tips = px.data.tips(pretty_names=True)

sns.scatterplot(
    data=tips,
    x='Total Bill',
    y='Tip',
    hue='Payer Gender',
    size='Day of Week',
    style='Smokers at Table',
    palette='pastel',
    legend='auto'
);

# %%
from matplotlib import pyplot as plt

tips = px.data.tips(pretty_names=True)

plt.figure(dpi=100)
plt.scatter(x=tips['Total Bill'], y=tips['Tip'], s=tips['Tip'], c=tips['Tip'], cmap='viridis')
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.tight_layout()
plt.colorbar()
plt.show()

# %%
tips
# Out:
#      Total Bill   Tip Payer Gender Smokers at Table Day of Week    Meal  \
# 0         16.99  1.01       Female               No         Sun  Dinner
# 1         10.34  1.66         Male               No         Sun  Dinner
# 2         21.01  3.50         Male               No         Sun  Dinner
# 3         23.68  3.31         Male               No         Sun  Dinner
# 4         24.59  3.61       Female               No         Sun  Dinner
# ..          ...   ...          ...              ...         ...     ...
# 239       29.03  5.92         Male               No         Sat  Dinner
# 240       27.18  2.00       Female              Yes         Sat  Dinner
# 241       22.67  2.00         Male              Yes         Sat  Dinner
# 242       17.82  1.75         Male               No         Sat  Dinner
# 243       18.78  3.00       Female               No        Thur  Dinner
#
#      Party Size
# 0             2
# 1             3
# 2             3
# 3             2
# ...

# %%
import plotly.offline as pyo
import plotly.graph_objects as go

px.
# Out:
# <module 'plotly.express.data' from '/Users/sammy/opt/anaconda3/lib/python3.9/site-packages/plotly/express/data/__init__.py'>

# %%
tips = px.data.tips(pretty_names=True)
tips.sample(n=3)
# Out:
#      Total Bill   Tip Payer Gender Smokers at Table Day of Week    Meal  \
# 19        20.65  3.35         Male               No         Sat  Dinner
# 103       22.42  3.48       Female              Yes         Sat  Dinner
# 14        14.83  3.02       Female               No         Sun  Dinner
#
#      Party Size
# 19            3
# 103           2
# 14            2

# %%
import plotly.offline as pyo
import plotly.graph_objects as go

tips = px.data.tips(pretty_names=True)

trace = go.Scatter(
    x=tips['Total Bill'],
    y=tips['Tip'],
    mode='markers',
    marker=dict(
        size=5,
        color='rgb(10,112,32)',
        symbol='pentagon'
    )
)

layout = go.Layout(
    title='Tip by Total Bill',
    xaxis=dict(
        title='Total Bill'
    ),
    yaxis=dict(
        title='Tip'
    )
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig, filename='temp-plot.html')
# Out:
# 'temp-plot.html'
